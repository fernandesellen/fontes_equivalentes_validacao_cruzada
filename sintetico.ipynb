# %%
! pip install verde harmonica pandas matplotlib
# Out:
# Requirement already satisfied: verde in c:\users\laisr\miniforge3\lib\site-packages (1.8.1)
# Requirement already satisfied: harmonica in c:\users\laisr\miniforge3\lib\site-packages (0.6.0.post87+ga05157d)
# Requirement already satisfied: pandas in c:\users\laisr\miniforge3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\laisr\miniforge3\lib\site-packages (3.9.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\laisr\miniforge3\lib\site-packages (from verde) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in c:\users\laisr\miniforge3\lib\site-packages (from verde) (1.13.1)
# Requirement already satisfied: xarray>=2022.03 in c:\users\laisr\miniforge3\lib\site-packages (from verde) (2024.5.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\laisr\miniforge3\lib\site-packages (from verde) (1.5.0)
# Requirement already satisfied: pooch>=1.2 in c:\users\laisr\miniforge3\lib\site-packages (from verde) (1.8.2)
# Requirement already satisfied: dask>=2022.01.0 in c:\users\laisr\miniforge3\lib\site-packages (from verde) (2024.5.2)
# Requirement already satisfied: numba>=0.53 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica) (0.59.1)
# Requirement already satisfied: xrft>=1.0 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica) (1.0.1)
# Requirement already satisfied: choclo>=0.1 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laisr\miniforge3\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laisr\miniforge3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laisr\miniforge3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\laisr\miniforge3\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\laisr\miniforge3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laisr\miniforge3\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\laisr\miniforge3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\laisr\miniforge3\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\laisr\miniforge3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\laisr\miniforge3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: click>=8.1 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde) (2024.6.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde) (7.1.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\laisr\miniforge3\lib\site-packages (from numba>=0.53->harmonica) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\laisr\miniforge3\lib\site-packages (from pooch>=1.2->verde) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\laisr\miniforge3\lib\site-packages (from pooch>=1.2->verde) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\laisr\miniforge3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\laisr\miniforge3\lib\site-packages (from scikit-learn>=1.0->verde) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\laisr\miniforge3\lib\site-packages (from scikit-learn>=1.0->verde) (3.5.0)
# Requirement already satisfied: colorama in c:\users\laisr\miniforge3\lib\site-packages (from click>=8.1->dask>=2022.01.0->verde) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\laisr\miniforge3\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2022.01.0->verde) (3.17.0)
# Requirement already satisfied: locket in c:\users\laisr\miniforge3\lib\site-packages (from partd>=1.2.0->dask>=2022.01.0->verde) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde) (2024.2.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import harmonica as hm
import verde as vd
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# Gerando a malha dos levantamentos

# %%
region = [0, 100e3, 0, 90e3]
# Coordenadas do levantamento terrestre
coordinates_t = vd.scatter_points(region, size=1000, extra_coords=1000, random_state=123)
# Espaçamento entre as linhas de voo
spacing = (500,5000) 
# Coordenadas do levantamento aéreo
coordinates_a = vd.grid_coordinates(region=region, spacing=spacing, extra_coords=500) 

fig, axes = plt.subplots(1,2,sharey=True, figsize=(10, 4.5)) #linha, coluna

axes[0].plot(coordinates_t[0], coordinates_t[1], ".k")
axes[0].set_ylabel("Northing (m)")
axes[0].set_xlabel("Easting (m)")
axes[0].grid()
axes[0].set_title("Levantamento terrestre")
axes[0].text(0,1.02,"a)", transform=axes[0].transAxes)
axes[1].plot(coordinates_a[0], coordinates_a[1],'o', color='black')
axes[1].set_xlabel("Easting (m)")
axes[1].grid()
axes[1].set_title("Levantamento aéreo")
axes[1].text(0,1.02,"b)", transform=axes[1].transAxes)


#plt.figure()
#plt.plot(coordinates_t[0], coordinates_t[1], ".k")
#plt.xlabel("Easting (m)")
#plt.ylabel("Northing (m)")
#plt.legend()
#plt.figure()
#plt.plot(coordinates_a[0], coordinates_a[1],'o', color='black')
#plt.xlabel("Easting (m)")
#plt.ylabel("Northing (m)")
#plt.legend()
# Out:
# Text(0, 1.02, 'b)')

# %%
# mudar o sintético 

# complicar o aereo
# perturbar as linhas
# adicionar linha de voo em sentido diferente 
# concatenar (np.concatenate e ravel)

# %% [markdown]
# Gerando o efeito gravitacional dos prismas

# %%
# Gerando os prismas 
prismas = [
    [10e3, 15e3, 20e3, 35e3, -1e3,  0],
    [60e3, 80e3, 50e3, 70e3, -2e3,  -0.5e3],
]
densidades = [500, -300]
# Efeito gravitacional dos prismas
gz_t = hm.prism_gravity(coordinates_t, prismas, densidades, field="g_z") # Terrestre
gz_a = hm.prism_gravity(coordinates_a, prismas, densidades, field="g_z") # Aéreo

fig, axes = plt.subplots(1,2,sharey=True, figsize=(10, 3.5)) #linha, coluna

ax0 = axes[0].scatter(coordinates_t[0], coordinates_t[1], s=5, c=gz_t)
axes[0].scatter(coordinates_t[0], coordinates_t[1], s=5, c=gz_t)
plt.colorbar(ax0, ax=axes[0], label="g_z [mGal]")
axes[0].set_ylabel("Northing (m)")
axes[0].set_xlabel("Easting (m)")
axes[0].grid()
axes[0].set_title("Levantamento terrestre")
axes[0].text(0,1.02,"a)", transform=axes[0].transAxes)

ax1 = axes[1].scatter(coordinates_a[0],coordinates_a[1],s=5,c=gz_a)
axes[1].scatter(coordinates_a[0],coordinates_a[1],s=5,c=gz_a)
axes[1].scatter(coordinates_a[0],coordinates_a[1],s=5,c=gz_a)
plt.colorbar(ax1, ax=axes[1], label="g_z [mGal]")
axes[1].set_xlabel("Easting (m)")
axes[1].grid()
axes[1].set_title("Levantamento aéreo")
axes[1].text(0,1.02,"b)", transform=axes[1].transAxes)


#plt.figure()
#plt.scatter(coordinates_t[0], coordinates_t[1], s=5, c=gz_t)
#plt.colorbar(label="g_z")
#plt.xlabel("Easting (m)")
#plt.ylabel("Northing (m)")
#plt.legend()
#plt.figure()
#plt.scatter(coordinates_a[0],coordinates_a[1],s=5,c=gz_a)
#plt.colorbar()
#plt.xlabel("Easting (m)")
#plt.ylabel("Northing (m)")
#plt.legend()
# Out:
# Text(0, 1.02, 'b)')

# %% [markdown]
# Ajustando um modelo de fontes de equivalentes

# %%
# Ajustando modelo de fontes equivalentes ao levantamento terrestre
fontes_t = hm.EquivalentSourcesGB(damping=1,depth=2e3)
fontes_t.fit([coordinates_t[0],coordinates_t[1],coordinates_t[2]],data=gz_t)
# Out:
# EquivalentSourcesGB(damping=1, depth=2000.0)

# %%
# Ajustando modelo de fontes equivalentes ao levantamento aéreo
fontes_a = hm.EquivalentSourcesGB(damping=1,depth=2e3)
fontes_a.fit([coordinates_a[0],coordinates_a[1],coordinates_a[2]],data=gz_a)
# Out:
# EquivalentSourcesGB(damping=1, depth=2000.0)

# %% [markdown]
# Gerando a malha do modelo de fontes equivalentes com espaçamento de 2000m

# %%
# Levantamento terrestre
grid_coords_eq_t = vd.grid_coordinates(region,spacing=2e3,extra_coords=1000)
gz_grid_eq_t = fontes_t.grid(grid_coords_eq_t,data_names="g_z")

# Levantamento aérero
grid_coords_eq_a = vd.grid_coordinates(region,spacing=2e3,extra_coords=500)
gz_grid_eq_a = fontes_a.grid(grid_coords_eq_a,data_names="g_z")

fig, axes = plt.subplots(1,2,sharey=True, figsize=(10, 3.5)) #linha, coluna

gz_grid_eq_t.g_z.plot(ax=axes[0])
gz_grid_eq_a.g_z.plot(ax=axes[1])

axes[0].set_ylabel("Northing (m)")
axes[0].set_xlabel("Easting (m)")
axes[0].set_title("Levantamento terrestre")
axes[0].text(0,1.02,"a)", transform=axes[0].transAxes)

axes[1].set_ylabel(" ")
axes[1].set_xlabel("Easting (m)")
axes[1].set_title("Levantamento aéreo")
axes[1].text(0,1.02,"b)", transform=axes[1].transAxes)
#plt.figure()
#gz_grid_eq_t.g_z.plot()
#plt.xlabel("Easting (m)")
#plt.ylabel("Northing (m)")
#plt.legend()
#plt.figure()
#gz_grid_eq_a.g_z.plot()
#plt.xlabel("Easting (m)")
#plt.ylabel("Northing (m)")
#plt.legend()
# Out:
# Text(0, 1.02, 'b)')

# %% [markdown]
# Reamostrando os dados numa malha regular ("verdadeira"). Objetivo: calcular o resíduo, ou seja, a diferença entre a malha "verdadeira" e a malha dos modelos de fontes equivalentes.

# %%
# Coordenadas da malha regular 
grid_coords = vd.grid_coordinates(region, spacing=2e3, extra_coords=1000)
# Efeito gravitacional dos prismas na malha regular
gz_grid = hm.prism_gravity(grid_coords, prismas, densidades, field="g_z")
# Malha regular: "verdadeira"
grid_true = vd.make_xarray_grid(grid_coords, gz_grid, data_names="g_z", extra_coords_names="upward")

grid_true.g_z.plot()
plt.xlabel("Easting (m)")
plt.ylabel("Northing (m)")
plt.legend()

# %% [markdown]
# Resíduo.

# %%
fig, axes = plt.subplots(1,3,sharey=True, figsize=(10, 2.5)) #linha, coluna

gz_grid_eq_t.g_z.plot(ax=axes[0])
gz_grid_eq_a.g_z.plot(ax=axes[1])
grid_true.g_z.plot(ax=axes[2])

axes[0].set_ylabel("Northing (m)")
axes[0].set_xlabel("Easting (m)")
#axes[0].set_title("Levantamento terrestre")
axes[0].text(0,1.02,"a) Levantamento terrestre", transform=axes[0].transAxes)

axes[1].set_ylabel(" ")
axes[1].set_xlabel("Easting (m)")
#axes[1].set_title("Levantamento aéreo")
axes[1].text(0,1.02,"b) Levantamento aéreo", transform=axes[1].transAxes)

axes[2].set_ylabel(" ")
axes[2].set_xlabel("Easting (m)")
#axes[2].set_title("Malha verdadeira")
axes[2].text(0,1.02,"c) Malha verdadeira", transform=axes[2].transAxes)
# Out:
# Text(0, 1.02, 'c) Malha verdadeira')

# %%
residuo_t = grid_true - gz_grid_eq_t # Terrestre
residuo_a = grid_true - gz_grid_eq_a # Aéreo

fig, axes = plt.subplots(1,2,sharey=True, figsize=(10, 3.5)) #linha, coluna

residuo_t.g_z.plot(ax=axes[0])
residuo_a.g_z.plot(ax=axes[1])

axes[0].set_ylabel("Northing (m)")
axes[0].set_xlabel("Easting (m)")
axes[0].set_title("Levantamento terrestre")
axes[0].text(0,1.02,"a)", transform=axes[0].transAxes)

axes[1].set_ylabel(" ")
axes[1].set_xlabel("Easting (m)")
axes[1].set_title("Levantamento aéreo")
axes[1].text(0,1.02,"b)", transform=axes[1].transAxes)
# Out:
# Text(0, 1.02, 'b)')

# %% [markdown]
# Calculando o coeficiente R_2 verdadeiro

# %%
g_z_medio_t = np.sum(gz_grid_eq_t.g_z.values)/np.size(gz_grid_eq_t.g_z)
g_z_medio_a = np.sum(gz_grid_eq_a.g_z.values)/np.size(gz_grid_eq_a.g_z)
# Levantamento terrestre
residuo_quadrado_t = np.sum(residuo_t.g_z.values**2)
R_2_true_t = 1 - (residuo_quadrado_t/np.sum([(gz - g_z_medio_t)**2 for gz in gz_grid_eq_t.g_z.values]))
# Levantamento aéreo
residuo_quadrado_a = np.sum(residuo_a.g_z.values**2)
R_2_true_a = 1 - (residuo_quadrado_a/np.sum([(gz - g_z_medio_a)**2 for gz in gz_grid_eq_a.g_z.values]))

print(f"R² verdadeiro terrestre: {R_2_true_t}\n R² verdadeiro aéreo: {R_2_true_a}")
# Out:
# R² verdadeiro terrestre: 0.9750645523020796
#  R² verdadeiro aéreo: 0.9784114959901214

# %% [markdown]
# Usando validação cruzada por blocos (block k-Fold) para avaliar quão bem o modelo de fontes equivalentes consegue prever com precisão os valores do campo

# %%
# Dados são primeiramente agrupados em blocos retangulares de tamanhos fornecimento pelo argumento "spacing".
# Os blocos são então divididos em teste e treinamento iterivamente através dos k folds do dado.
# (k é dado por "n_splits")


# Variando tamanho do bloco através de 5 folds do dado (n_splits = 5)

# Levantamento terrestre
block = np.arange(1000,10950,950) 
nsplits = 5
R_2_block_t = [] # Estou adicionando o valor médio de R²

for spacing in block:
    R_2_block_t.append(np.mean(
        vd.cross_val_score(
            fontes_t,
            coordinates_t,
            gz_t,
            cv=vd.BlockKFold(spacing=spacing, n_splits=nsplits, shuffle=True, random_state=123),
        )
    ))

# %%
# Levantamento aéreo
block = np.arange(1000,10950,950) 
nsplits = 5
R_2_block_a = [] # Estou adicionando o valor médio de R²

for spacing in block:
    R_2_block_a.append(np.mean(
        vd.cross_val_score(
            fontes_a,
            coordinates_a,
            gz_a,
            cv=vd.BlockKFold(spacing=spacing, n_splits=nsplits, shuffle=True, random_state=123),
        )
    ))

# %%
fig, axes = plt.subplots(1,2,sharey=True, figsize=(10, 4.5)) #linha, coluna

axes[0].plot(block,R_2_block_t,"o", color='black')
axes[0].set_ylabel("R²")
axes[0].set_xlabel("Tamanho do bloco (m)")
axes[0].grid()
axes[0].set_title("Levantamento terrestre")
axes[0].text(0,1.02,"a)", transform=axes[0].transAxes)
axes[0].axhline(y = R_2_true_t, color = 'red', linestyle = 'dotted', label="R² verdadeiro") 
axes[0].legend()
axes[0].grid(True)
axes[1].plot(block,R_2_block_a,"o", color='black')
axes[1].set_xlabel("Tamanho do bloco (m)")
axes[1].grid()
axes[1].set_title("Levantamento aéreo")
axes[1].text(0,1.02,"b)", transform=axes[1].transAxes)
axes[1].axhline(y = R_2_true_a, color = 'red', linestyle = 'dotted', label="R² verdadeiro") 
axes[1].legend()
axes[1].grid(True)

#plt.plot(block,R_2_block_t,"o")
#plt.xlabel("Tamanho do bloco (m)")
#plt.ylabel("R²")
#plt.axhline(y = R_2_true_t, color = 'red', linestyle = 'dotted', label="R² verdadeiro") 
#plt.grid(True)
#plt.legend()

#plt.plot(block,R_2_block_a,"o")
#plt.xlabel("Tamanho do bloco (m)")
#plt.ylabel("R²")
#plt.axhline(y = R_2_true_a, color = 'red', linestyle = 'dotted', label="R² verdadeiro") 
#plt.grid(True)
#plt.legend()

# %%
# Variando n_splits (numero de folds do dado)

# Levantamento terrestre: blocos de 1000m

R_2_splits_t = []
n = np.arange(2,9)
for n_splits in n:
    R_2_splits_t.append(np.mean(
        vd.cross_val_score(
            fontes_t,
            coordinates_t,
            gz_t,
            cv=vd.BlockKFold(spacing=1000, n_splits=n_splits, shuffle=True, random_state=123),
        )
    ))

# %%
# Levantamento aéreo: blocos de 1000m

R_2_splits_a = []
n = np.arange(2,9)
for n_splits in n:
    R_2_splits_a.append(np.mean(
        vd.cross_val_score(
            fontes_a,
            coordinates_a,
            gz_a,
            cv=vd.BlockKFold(spacing=2000, n_splits=n_splits, shuffle=True, random_state=123),
        )
    ))

# %%
fig, axes = plt.subplots(1,2,sharey=True, figsize=(10, 4.5)) #linha, coluna

n=list(n)
axes[0].plot(n,R_2_splits_t,"o", color='black')
axes[0].set_ylabel("R²")
axes[0].set_xlabel("Número de folds")
axes[0].grid()
axes[0].set_title("Levantamento terrestre")
axes[0].text(0,1.02,"a)", transform=axes[0].transAxes)
axes[0].axhline(y = R_2_true_t, color = 'red', linestyle = 'dotted', label="R² verdadeiro") 
axes[0].legend()
axes[0].grid(True)
axes[1].plot(n,R_2_splits_a,"o", color='black')
axes[1].set_xlabel("Número de folds")
axes[1].grid()
axes[1].set_title("Levantamento aéreo")
axes[1].text(0,1.02,"b)", transform=axes[1].transAxes)
axes[1].axhline(y = R_2_true_a, color = 'red', linestyle = 'dotted', label="R² verdadeiro") 
axes[1].legend()
axes[1].grid(True)
