# %%
! pip install --upgrade git+https://github.com/fatiando/harmonica
# Out:
# Collecting git+https://github.com/fatiando/harmonica
#   Cloning https://github.com/fatiando/harmonica to c:\users\laisr\appdata\local\temp\pip-req-build-2eazjej5
#   Resolved https://github.com/fatiando/harmonica to commit b9f9c00b0999f470dcae971b19add28b055633c9
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.23 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (2.2.2)
# Requirement already satisfied: scipy>=1.9 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (1.5.0)
# Requirement already satisfied: numba>=0.53 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (0.59.1)
# Requirement already satisfied: xarray>=2022.03 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (2024.5.0)
# Requirement already satisfied: verde>=1.8.1 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (1.8.1)
# Requirement already satisfied: xrft>=1.0 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (1.0.1)
# Requirement already satisfied: choclo>=0.1 in c:\users\laisr\miniforge3\lib\site-packages (from harmonica==0.7.0) (0.2.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\laisr\miniforge3\lib\site-packages (from numba>=0.53->harmonica==0.7.0) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laisr\miniforge3\lib\site-packages (from pandas>=1.4->harmonica==0.7.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laisr\miniforge3\lib\site-packages (from pandas>=1.4->harmonica==0.7.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laisr\miniforge3\lib\site-packages (from pandas>=1.4->harmonica==0.7.0) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\laisr\miniforge3\lib\site-packages (from scikit-learn>=1.0->harmonica==0.7.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\laisr\miniforge3\lib\site-packages (from scikit-learn>=1.0->harmonica==0.7.0) (3.5.0)
# Requirement already satisfied: pooch>=1.2 in c:\users\laisr\miniforge3\lib\site-packages (from verde>=1.8.1->harmonica==0.7.0) (1.8.2)
# Requirement already satisfied: dask>=2022.01.0 in c:\users\laisr\miniforge3\lib\site-packages (from verde>=1.8.1->harmonica==0.7.0) (2024.5.2)
# Requirement already satisfied: packaging>=23.1 in c:\users\laisr\miniforge3\lib\site-packages (from xarray>=2022.03->harmonica==0.7.0) (24.0)
# Requirement already satisfied: click>=8.1 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (2024.6.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\laisr\miniforge3\lib\site-packages (from dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (7.1.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\laisr\miniforge3\lib\site-packages (from pooch>=1.2->verde>=1.8.1->harmonica==0.7.0) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\laisr\miniforge3\lib\site-packages (from pooch>=1.2->verde>=1.8.1->harmonica==0.7.0) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\laisr\miniforge3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4->harmonica==0.7.0) (1.16.0)
# Requirement already satisfied: colorama in c:\users\laisr\miniforge3\lib\site-packages (from click>=8.1->dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\laisr\miniforge3\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (3.17.0)
# Requirement already satisfied: locket in c:\users\laisr\miniforge3\lib\site-packages (from partd>=1.2.0->dask>=2022.01.0->verde>=1.8.1->harmonica==0.7.0) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde>=1.8.1->harmonica==0.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde>=1.8.1->harmonica==0.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde>=1.8.1->harmonica==0.7.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laisr\miniforge3\lib\site-packages (from requests>=2.19.0->pooch>=1.2->verde>=1.8.1->harmonica==0.7.0) (2024.7.4)
# Building wheels for collected packages: harmonica
#   Building wheel for harmonica (pyproject.toml): started
#   Building wheel for harmonica (pyproject.toml): finished with status 'done'
#   Created wheel for harmonica: filename=harmonica-0.7.0-py3-none-any.whl size=392129 sha256=ddb259dc9a3bc3bb86c5084deb35267239f9d2e3acb783609ce066036a840f10
#   Stored in directory: C:\Users\laisr\AppData\Local\Temp\pip-ephem-wheel-cache-lsceligr\wheels\69\14\bc\4d87f5c88ec7ebbfeade8beeda1000ef39755c4b3bf1f79834
# Successfully built harmonica
# Installing collected packages: harmonica
#   Attempting uninstall: harmonica
#     Found existing installation: harmonica 0.6.0.post87+ga05157d
#     Uninstalling harmonica-0.6.0.post87+ga05157d:
#       Successfully uninstalled harmonica-0.6.0.post87+ga05157d
# Successfully installed harmonica-0.7.0
#   Running command git clone --filter=blob:none --quiet https://github.com/fatiando/harmonica 'C:\Users\laisr\AppData\Local\Temp\pip-req-build-2eazjej5'

# %%
import numpy as np
import harmonica as hm
import verde as vd
import matplotlib.pyplot as plt
import xrft
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
region = [0, 100e3, 0, 90e3]
coordinates = vd.scatter_points(region, size=2000, extra_coords=2000, random_state=1)
inclination, declination = -20, -15
base_level = 500
noise_level = 200
main_field = hm.magnetic_angles_to_vec(1, inclination, declination)

# Dipoles
dipole_coordinates = (20e3, 15e3, 1e3)
magnetic_field = hm.dipole_magnetic(
    coordinates,
    dipoles=dipole_coordinates,
    magnetic_moments=hm.magnetic_angles_to_vec(7e10, inclination, declination),
    field="b",
)
magnetic_anomaly = sum(b * f for b, f in zip(magnetic_field, main_field))
dipole2_coordinates = (20e3, 80e3, 0e3)
magnetic_field = hm.dipole_magnetic(
    coordinates,
    dipoles=dipole2_coordinates,
    magnetic_moments=hm.magnetic_angles_to_vec(5e11, inclination, declination),
    field="b",
)
magnetic_anomaly += sum(b * f for b, f in zip(magnetic_field, main_field))

# Pipe
size = 70
pipe_coordinates = (60e3, 80e3, 500)
magnetic_field = hm.prism_magnetic(
    coordinates,
    prisms=[
        pipe_coordinates[0] - size,
        pipe_coordinates[0] + size,
        pipe_coordinates[1] - size,
        pipe_coordinates[1] + size,
        pipe_coordinates[2] - 10e3,
        pipe_coordinates[2],
    ],
    magnetization=hm.magnetic_angles_to_vec(15e3, -90, 0),
    field="b",
)
magnetic_anomaly += sum(b * f for b, f in zip(magnetic_field, main_field))
# Dike
dike_coordinates = (30e3, 30e3, 900)
magnetic_field = hm.prism_magnetic(
    coordinates,
    prisms=[
        dike_coordinates[0] - 100e3,
        dike_coordinates[0] + 100e3,
        dike_coordinates[1] - 100,
        dike_coordinates[1] + 100,
        dike_coordinates[2] - 7e3,
        dike_coordinates[2],
    ],
    magnetization=hm.magnetic_angles_to_vec(200, inclination, declination),
    field="b",
)
magnetic_anomaly += sum(b * f for b, f in zip(magnetic_field, main_field))

# Line
line_coordinates = [30e3, 50e3, 0]
magnetic_field = hm.prism_magnetic(
    coordinates,
    prisms=[
        line_coordinates[0] - 50,
        line_coordinates[0] + 50,
        line_coordinates[1],
        line_coordinates[1] + 100e3,
        line_coordinates[2] - 50,
        line_coordinates[2] + 50,
    ],
    magnetization=hm.magnetic_angles_to_vec(25e3, inclination, declination),
    field="b",
)
magnetic_anomaly += sum(b * f for b, f in zip(magnetic_field, main_field))

# Sill
sill_coordinates = [80e3, 25e3, -0.5e3]
magnetic_field = hm.prism_magnetic(
    coordinates,
    prisms=[
        sill_coordinates[0] - 10e3,
        sill_coordinates[0] + 10e3,
        sill_coordinates[1] - 15e3,
        sill_coordinates[1] + 15e3,
        sill_coordinates[2] - 100,
        sill_coordinates[2] + 100,
    ],
    magnetization=hm.magnetic_angles_to_vec(200, inclination, declination),
    field="b",
)
magnetic_anomaly += sum(b * f for b, f in zip(magnetic_field, main_field))
# Regional
magnetic_anomaly += 0.01 * coordinates[0] - 0.02 * coordinates[1]

# Add noise and the base level
magnetic_anomaly += np.random.default_rng(42).normal(
    0, noise_level, size=magnetic_anomaly.shape
)
magnetic_anomaly += base_level

# %%
plt.scatter(coordinates[0], coordinates[1], s=5, c=magnetic_anomaly)
plt.colorbar()

# %%
# Equivalent sources

fonts = hm.EquivalentSourcesGB(damping=1,depth=1e3)
fonts.fit([coordinates[0],coordinates[1],coordinates[2]],data=magnetic_anomaly)
# Out:
# EquivalentSourcesGB(damping=1, depth=1000.0)

# %%
# Gridding equivalent sources

grid_coords_eq = vd.grid_coordinates(region,spacing=1e3,extra_coords=2e3)
grid_eq = fonts.grid(grid_coords_eq,data_names="field")

grid_eq.field.plot()
plt.title("Equivalent sources")
# Out:
# Text(0.5, 1.0, 'Equivalent sources')

# %%
# Regular grid

coordinates_grid = vd.grid_coordinates(region, spacing=1000, extra_coords=2000)

# Multiple sources on regular grid
# Dipoles
dipole_coordinates = (20e3, 15e3, 1e3)
magnetic_field_grid = hm.dipole_magnetic(
    coordinates_grid,
    dipoles=dipole_coordinates,
    magnetic_moments=hm.magnetic_angles_to_vec(7e10, inclination, declination),
    field="b",
)
magnetic_anomaly_grid = sum(b * f for b, f in zip(magnetic_field_grid, main_field))
dipole2_coordinates = (20e3, 80e3, 0e3)
magnetic_field_grid = hm.dipole_magnetic(
    coordinates_grid,
    dipoles=dipole2_coordinates,
    magnetic_moments=hm.magnetic_angles_to_vec(5e11, inclination, declination),
    field="b",
)
magnetic_anomaly_grid += sum(b * f for b, f in zip(magnetic_field_grid, main_field))

# Pipe
size = 70
pipe_coordinates = (60e3, 80e3, 500)
magnetic_field_grid = hm.prism_magnetic(
    coordinates_grid,
    prisms=[
        pipe_coordinates[0] - size,
        pipe_coordinates[0] + size,
        pipe_coordinates[1] - size,
        pipe_coordinates[1] + size,
        pipe_coordinates[2] - 10e3,
        pipe_coordinates[2],
    ],
    magnetization=hm.magnetic_angles_to_vec(15e3, -90, 0),
    field="b",
)
magnetic_anomaly_grid += sum(b * f for b, f in zip(magnetic_field_grid, main_field))
# Dike
dike_coordinates = (30e3, 30e3, 900)
magnetic_field_grid = hm.prism_magnetic(
    coordinates_grid,
    prisms=[
        dike_coordinates[0] - 100e3,
        dike_coordinates[0] + 100e3,
        dike_coordinates[1] - 100,
        dike_coordinates[1] + 100,
        dike_coordinates[2] - 7e3,
        dike_coordinates[2],
    ],
    magnetization=hm.magnetic_angles_to_vec(200, inclination, declination),
    field="b",
)
magnetic_anomaly_grid += sum(b * f for b, f in zip(magnetic_field_grid, main_field))

# Line
line_coordinates = [30e3, 50e3, 0]
magnetic_field_grid = hm.prism_magnetic(
    coordinates_grid,
    prisms=[
        line_coordinates[0] - 50,
        line_coordinates[0] + 50,
        line_coordinates[1],
        line_coordinates[1] + 100e3,
        line_coordinates[2] - 50,
        line_coordinates[2] + 50,
    ],
    magnetization=hm.magnetic_angles_to_vec(25e3, inclination, declination),
    field="b",
)
magnetic_anomaly_grid += sum(b * f for b, f in zip(magnetic_field_grid, main_field))

# Sill
sill_coordinates = [80e3, 25e3, -0.5e3]
magnetic_field_grid = hm.prism_magnetic(
    coordinates_grid,
    prisms=[
        sill_coordinates[0] - 10e3,
        sill_coordinates[0] + 10e3,
        sill_coordinates[1] - 15e3,
        sill_coordinates[1] + 15e3,
        sill_coordinates[2] - 100,
        sill_coordinates[2] + 100,
    ],
    magnetization=hm.magnetic_angles_to_vec(200, inclination, declination),
    field="b",
)
magnetic_anomaly_grid += sum(b * f for b, f in zip(magnetic_field_grid, main_field))
# Regional
magnetic_anomaly_grid += 0.01 * coordinates_grid[0] - 0.02 * coordinates_grid[1]


grid_true = vd.make_xarray_grid(
    coordinates_grid[:2], (magnetic_anomaly_grid, coordinates_grid[-1]), data_names=["field", "height"]
)
grid_true.field.plot()
plt.title("Regular grid")
# Out:
# Text(0.5, 1.0, 'Regular grid')

# %%
residuo = grid_true - grid_eq
print(np.min(residuo.field.values))
print(np.max(residuo.field.values))
print(np.mean(residuo.field.values))
print("__")
print(np.min(grid_true.field.values))
print(np.max(grid_true.field.values))
print(np.mean(grid_true.field.values))
residuo.field.plot()
plt.title("Residuo")
# Out:
# -4388.877872011086
# 5382.14815265283
# -491.7671109663744
# __
# -5715.775702817908
# 6034.114477414175
# -439.2304989573785
# Text(0.5, 1.0, 'Residuo')

# %%
media = np.sum(grid_eq.field.values)/np.size(grid_eq.field)
residuo_2 = np.sum(residuo.field.values**2)
R_2_true = 1 - (residuo_2/np.sum([(value - media)**2 for value in grid_eq.field.values]))
R_2_true
# Out:
# 0.46909147367062143

# %%
# Random cross-validation 

R_2_random = np.mean(vd.cross_val_score(fonts,coordinates,magnetic_anomaly))
R_2_random
# Out:
# 0.8244458264042466

# %%
# Blocked cross-validation

block = np.arange(1000,10950,950) 
nsplits = 5
R_2_block = [] 

for spacing in block:
    R_2_block.append(np.mean(
        vd.cross_val_score(
            fonts,
            coordinates,
            magnetic_anomaly,
            cv=vd.BlockKFold(spacing=spacing, n_splits=nsplits, shuffle=True, random_state=123),
        )
    ))

# %%
plt.plot(block,R_2_block,".k")
plt.xlabel("block size")
plt.ylabel("R²")
plt.axhline(y = R_2_true, color = 'red', linestyle = 'dotted', label="R² true") 
plt.axhline(y = R_2_random, color = 'blue', linestyle = 'dotted', label="R² random") 
plt.grid(True)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(block,R_2_block,".k")
#       2 plt.xlabel("block size")
#       3 plt.ylabel("R²")
#
# NameError: name 'plt' is not defined
